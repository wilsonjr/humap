# %%
import os
import scprep
import demap
import math
import random
import numpy as np
import pandas as pd
import hierarchical_umap as h_umap
import matplotlib.pyplot as plt

from tqdm import tqdm
from sklearn.neighbors import NearestNeighbors
from sklearn.utils import check_array
from sklearn.preprocessing import normalize, LabelEncoder
from sklearn.decomposition import PCA
from sklearn.metrics import euclidean_distances
from sklearn.neighbors import NearestNeighbors

from scipy.stats import pearsonr, spearmanr

# %%
def correlation(X, X_emb):
    
    dist_orig = np.square(euclidean_distances(X, X)).flatten()
    dist_emb = np.square(euclidean_distances(X_emb, X_emb)).flatten()
    
    
    coef, p = spearmanr(dist_orig, dist_emb)
    return coef

def stress(X, X_emb):
    
    DE = euclidean_distances(X_emb)
    DE = DE/np.max(DE)
    DH = euclidean_distances(X)
    DH = DH/np.max(DH)
    stress = 0.5 * np.sum((DE - DH)**2)
    
    return np.sqrt(stress/(0.5*np.sum(DH**2)))
    

def neighborhood_preservation(X, X_emb, Khigh=30):
    
    neigh_high = NearestNeighbors(n_neighbors=Khigh+1, n_jobs=-1)
    neigh_high.fit(X)
    high_dists, high_indices = neigh_high.kneighbors(X)


    neigh_emb = NearestNeighbors(n_neighbors=Khigh+1, n_jobs=-1)
    neigh_emb.fit(X_emb)
    emb_dists, emb_indices = neigh_emb.kneighbors(X_emb)

    npres = np.zeros(Khigh)
    
    for k in range(1, Khigh+1):
        for i in range(X.shape[0]):
            high_current = high_indices[i][1:k+1]
            emb_current = emb_indices[i][1:k+1]
            
            tp = len(np.intersect1d(high_current, emb_current))
            
            npres[k-1] += (tp/k)
        
        
    npres /= float(X.shape[0])
    
    return npres

# %%
def load_fmnist():
    fashionTrain = pd.read_csv('data/fashion-train.csv')

    fashionX = fashionTrain.values[:,2:]
    fashionY = fashionTrain.values[:, 1].astype(int)

    X = normalize(fashionX)
    y = fashionY

    X = check_array(X, dtype=np.float32, accept_sparse='csr', order='C')
    
    return X, y

def load_mnist():
    X = np.load('./data/MNIST_70000.npy')
    y = np.load('./data/MNIST_70000_label.npy').astype(int)
    X = normalize(X)
    X = check_array(X, dtype=np.float32, accept_sparse='csr', order='C')
    
    return X, y

def load_scRNAseq():
    download_path = os.path.expanduser("~/Documentos/HierarchicalUMAP/umap-cpp/umap/cpp/data")
    sparse=True
    T1 = scprep.io.load_10X(os.path.join(download_path, "scRNAseq", "T0_1A"), sparse=sparse, gene_labels='both')
    T2 = scprep.io.load_10X(os.path.join(download_path, "scRNAseq", "T2_3B"), sparse=sparse, gene_labels='both')
    T3 = scprep.io.load_10X(os.path.join(download_path, "scRNAseq", "T4_5C"), sparse=sparse, gene_labels='both')
    T4 = scprep.io.load_10X(os.path.join(download_path, "scRNAseq", "T6_7D"), sparse=sparse, gene_labels='both')
    T5 = scprep.io.load_10X(os.path.join(download_path, "scRNAseq", "T8_9E"), sparse=sparse, gene_labels='both')
    filtered_batches = []
    for batch in [T1, T2, T3, T4, T5]:
        batch = scprep.filter.filter_library_size(batch, percentile=20, keep_cells='above')
        batch = scprep.filter.filter_library_size(batch, percentile=75, keep_cells='below')
        filtered_batches.append(batch)
    del T1, T2, T3, T4, T5
    EBT_counts, sample_labels = scprep.utils.combine_batches(
        filtered_batches, 
        ["Day 00-03", "Day 06-09", "Day 12-15", "Day 18-21", "Day 24-27"],
        append_to_cell_names=True
    )
    del filtered_batches # removes objects from memory
    EBT_counts = scprep.filter.filter_rare_genes(EBT_counts, min_cells=10)
    EBT_counts = scprep.normalize.library_size_normalize(EBT_counts)
    mito_genes = scprep.select.get_gene_set(EBT_counts, starts_with="MT-") # Get all mitochondrial genes. There are 14, FYI.
    EBT_counts, sample_labels = scprep.filter.filter_gene_set_expression(
    EBT_counts, sample_labels, genes=mito_genes, 
    percentile=90, keep_cells='below')
    EBT_counts = scprep.transform.sqrt(EBT_counts)
    
    le = LabelEncoder()
    le.fit(sample_labels)
    labels = le.transform(sample_labels)
    X = PCA(n_components=50).fit_transform(EBT_counts.values)
    X = check_array(X, dtype=np.float32, accept_sparse='csr', order='C')
    return X, labels

def load_mammals():
    X = np.loadtxt("data/mammals-20000_features.txt")
    y = np.loadtxt("data/mammals-20000_classes.txt")
    X = normalize(X)
    
    return X, y

# %%
datasets = []
datasets.append({
    'load': load_mammals,
    'name': 'mammals-drill'
})
# datasets.append({
#     'load': load_scRNAseq,
#     'name': 'scRNAseq'
# })
datasets.append({
    'load': load_fmnist,
    'name': 'fmnist-drill'
})
# datasets.append({
#     'load': load_mnist,
#     'name': 'mnist'
# })

# %%
def compute_metrics(datasets, techniques = ['hsne', 'humap'], n_executions = 20):
    map_name = {}
    map_name['hsne'] = 'HSNE'
    map_name['humap'] = 'HUMAP'
    
    
    corr_values = []
    corr_level = []
    corr_technique = []
    
    demap_values = []
    demap_level = []
    demap_technique = []
    
    neighborhood_values = []
    np_values = []
    np_level = []
    np_technique = []
    
    dataset_values_corr = []
    dataset_values_demap = []
    dataset_values_np = []
    
    size_before_corr = 0
    size_before_demap = 0
    size_before_np = 0
    
    for dataset in datasets:
        
        path = 'experiments/comparison/'+dataset['name']
        X, y = dataset['load']()
        
        print("DATASET: %s" % (dataset['name']))
        
                
        for technique in techniques:
            print("Technique: %s" % (technique))
                
            for i, level in enumerate(['_TOP.csv', '_level1.csv', '_level0.csv']):
                
                print("Level: %s" % (level))
                
                demap_list = []
                correlation_list = []
                np_list = []

                for execution in tqdm(range(n_executions)):
                    it = str(execution)
                    
                    df = pd.read_csv(path+'/'+technique+'_it'+it+level)
                    x = df['x'+it].values
                    y = df['y'+it].values
                    indices = df['inds'+it].values
                    
                    emb = np.stack((x, y), axis=-1)
                    sample = random.sample(range(0, len(x)), min(3000, len(x)))
                    
                    subset_emb = emb[sample]
                    subset_X = X[indices][sample]
                    
                    demap_value = demap.DEMaP(subset_X, subset_emb)
                    demap_list.append(demap_value)
                    
                    corr_value = correlation(subset_X, subset_emb)
                    correlation_list.append(corr_value)
                    
                    npres_values = neighborhood_preservation(subset_X, subset_emb)
                    np_list = np_list + npres_values.tolist()
                    
                    
                corr_values = corr_values + correlation_list
                corr_technique = corr_technique + [map_name[technique]]*len(correlation_list)
                level = 'Top'
                if i == 0:
                    level = 'Top'
                elif i == 1:
                    level = '1'
                elif i == 2:
                    level = '0'
                corr_level = corr_level + ['Level '+str(level)]*len(correlation_list)
                
                demap_values = demap_values + demap_list
                demap_technique = demap_technique + [map_name[technique]]*len(demap_list)
                demap_level = demap_level + ['Level '+str(level)]*len(demap_list)
                
                np_values = np_values + np_list
                neighborhood_values = neighborhood_values + list(range(30))*n_executions
                np_technique = np_technique + [map_name[technique]]*len(np_list)
                np_level = np_level + ['Level '+str(level)]*len(np_list)
        
        
        dataset_values_corr = dataset_values_corr + [dataset['name']]*(len(corr_values) - size_before_corr)
        dataset_values_demap = dataset_values_demap + [dataset['name']]*(len(demap_values) - size_before_demap)
        dataset_values_np = dataset_values_np + [dataset['name']]*(len(np_values) - size_before_np)
        
        size_before_corr = len(corr_values)
        size_before_demap = len(demap_values)
        size_before_np = len(np_values)
        
        
        
    
    print(len(dataset_values_corr), len(corr_technique), len(corr_values))
    
    df_correlation = pd.DataFrame({
        'dataset': dataset_values_corr,
        'technique': corr_technique,
        'level': corr_level,
        'values': corr_values        
    })
    
    print(len(dataset_values_demap), len(demap_technique), len(demap_values))
    
    df_demap = pd.DataFrame({
        'dataset': dataset_values_demap,
        'technique': demap_technique,
        'level': demap_level,
        'values': demap_values
    })
    
    print(len(dataset_values_np), len(np_technique), len(neighborhood_values), len(np_values))
    
    
    df_np = pd.DataFrame({
        'dataset': dataset_values_np,
        'technique': np_technique,
        'level': np_level,
        'neighbors': neighborhood_values,
        'np': np_values
    })
        
    return df_correlation, df_demap, df_np

# %%
df_correlation, df_demap, df_np = compute_metrics(datasets, n_executions=20)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# DATASET: mammals-drill
# Technique: hsne
# Level: _TOP.csv
# 100%|██████████| 20/20 [00:16<00:00,  1.22it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Level: _level1.csv
# 100%|██████████| 20/20 [02:24<00:00,  7.25s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Level: _level0.csv
# 100%|██████████| 20/20 [02:39<00:00,  7.97s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Technique: humap
# Level: _TOP.csv
# 100%|██████████| 20/20 [00:16<00:00,  1.23it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Level: _level1.csv
# 100%|██████████| 20/20 [02:24<00:00,  7.24s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Level: _level0.csv
# 100%|██████████| 20/20 [02:39<00:00,  7.96s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]
# DATASET: fmnist-drill
# Technique: hsne
# Level: _TOP.csv
# /home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (1986, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#   5%|▌         | 1/20 [00:05<01:50,  5.81s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (1960, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:11<01:42,  5.72s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (1979, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:16<01:36,  5.70s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (1973, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:22<01:30,  5.65s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (1957, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [00:27<01:23,  5.58s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (1989, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [00:33<01:17,  5.56s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2111, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [00:39<01:15,  5.81s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (1990, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [00:45<01:08,  5.73s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2018, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [00:51<01:02,  5.73s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2037, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [00:56<00:57,  5.75s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2001, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [01:02<00:51,  5.70s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (1997, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [01:08<00:45,  5.67s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (1952, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [01:13<00:39,  5.59s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2003, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [01:18<00:32,  5.38s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2033, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [01:24<00:27,  5.56s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2108, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [01:30<00:23,  5.81s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2041, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [01:36<00:17,  5.87s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2046, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [01:42<00:11,  5.92s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2045, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [01:48<00:05,  5.88s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2009, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [01:54<00:00,  5.72s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# Level: _level1.csv
#   5%|▌         | 1/20 [00:12<04:01, 12.71s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:25<03:47, 12.65s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:37<03:33, 12.57s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:50<03:20, 12.55s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [01:02<03:08, 12.55s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [01:15<02:56, 12.60s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [01:27<02:43, 12.58s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [01:40<02:30, 12.56s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [01:52<02:18, 12.57s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [02:05<02:05, 12.59s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [02:18<01:53, 12.61s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [02:30<01:40, 12.61s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [02:43<01:28, 12.58s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [02:55<01:15, 12.54s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [03:08<01:02, 12.51s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [03:20<00:50, 12.53s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [03:33<00:37, 12.52s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [03:45<00:25, 12.53s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [03:58<00:12, 12.56s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [04:11<00:00, 12.56s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# Level: _level0.csv
#   5%|▌         | 1/20 [00:13<04:22, 13.84s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:27<04:07, 13.74s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:40<03:52, 13.68s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:54<03:38, 13.68s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [01:08<03:24, 13.64s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [01:21<03:10, 13.63s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [01:35<02:56, 13.55s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [01:48<02:42, 13.50s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [02:01<02:28, 13.50s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [02:15<02:14, 13.48s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [02:28<02:01, 13.49s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [02:42<01:47, 13.50s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [02:55<01:34, 13.51s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [03:09<01:21, 13.53s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [03:23<01:07, 13.52s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [03:36<00:54, 13.57s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [03:50<00:40, 13.54s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [04:03<00:27, 13.56s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [04:17<00:13, 13.57s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [04:30<00:00, 13.55s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (1986, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# Technique: humap
# Level: _TOP.csv
#   5%|▌         | 1/20 [00:05<01:49,  5.78s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (1959, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:11<01:42,  5.69s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (1979, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:16<01:35,  5.63s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (1973, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:22<01:29,  5.62s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (1957, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [00:27<01:23,  5.55s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (1989, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [00:33<01:17,  5.56s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2111, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [00:39<01:15,  5.84s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (1990, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [00:45<01:08,  5.75s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2017, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [00:51<01:03,  5.75s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2037, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [00:56<00:57,  5.79s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2001, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [01:02<00:51,  5.75s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (1997, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [01:08<00:45,  5.69s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (1952, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [01:13<00:39,  5.58s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2003, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [01:19<00:33,  5.63s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2033, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [01:25<00:28,  5.71s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2108, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [01:31<00:23,  5.92s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2041, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [01:37<00:17,  5.91s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2046, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [01:43<00:11,  5.87s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2045, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [01:49<00:05,  5.92s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2009, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [01:54<00:00,  5.75s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# Level: _level1.csv
#   5%|▌         | 1/20 [00:12<03:59, 12.59s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:25<03:46, 12.61s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:37<03:34, 12.62s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:50<03:20, 12.56s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [01:02<03:07, 12.51s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [01:15<02:55, 12.55s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [01:27<02:43, 12.56s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [01:40<02:30, 12.52s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [01:52<02:17, 12.52s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [02:04<02:01, 12.18s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [02:16<01:50, 12.25s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [02:29<01:38, 12.35s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [02:41<01:26, 12.40s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [02:54<01:14, 12.43s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [03:06<01:02, 12.46s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [03:19<00:50, 12.53s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [03:32<00:37, 12.57s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [03:44<00:25, 12.57s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [03:57<00:12, 12.57s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [04:09<00:00, 12.49s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# Level: _level0.csv
#   5%|▌         | 1/20 [00:13<04:18, 13.60s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:27<04:04, 13.60s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:41<03:52, 13.68s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:54<03:38, 13.63s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [01:08<03:24, 13.64s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [01:21<03:10, 13.61s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [01:35<02:57, 13.67s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [01:49<02:44, 13.69s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [02:03<02:30, 13.71s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [02:16<02:16, 13.65s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [02:30<02:02, 13.64s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [02:43<01:49, 13.67s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [02:57<01:35, 13.64s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [03:11<01:21, 13.60s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [03:24<01:07, 13.58s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [03:38<00:54, 13.57s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [03:51<00:40, 13.58s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [04:05<00:27, 13.55s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [04:18<00:13, 13.55s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [04:32<00:00, 13.61s/it]
# 240 240 240
# 240 240 240
# 7200 7200 7200 7200

# %%
df_correlation.to_csv('./correlation_values_drill.csv', index=False)
df_demap.to_csv('./demap_values_drill.csv', index=False)
df_np.to_csv('./n0p_values_drill.csv', index=False)

# %%
df_demap[df_demap['technique'] == 'HSNE CPU'][df_demap['dataset'] == 'mammals']
# Out:
# /home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#     dataset technique    level    values
# 0   mammals  HSNE CPU  Level 2  0.756441
# 1   mammals  HSNE CPU  Level 2  0.756594
# 2   mammals  HSNE CPU  Level 2  0.754914
# 3   mammals  HSNE CPU  Level 2  0.755382
# 4   mammals  HSNE CPU  Level 2  0.756958
# 5   mammals  HSNE CPU  Level 2  0.755487
# 6   mammals  HSNE CPU  Level 2  0.756064
# 7   mammals  HSNE CPU  Level 2  0.754787
# 8   mammals  HSNE CPU  Level 2  0.754383
# 9   mammals  HSNE CPU  Level 2  0.758107
# 10  mammals  HSNE CPU  Level 2  0.754942
# 11  mammals  HSNE CPU  Level 2  0.756204
# 12  mammals  HSNE CPU  Level 2  0.757184
# 13  mammals  HSNE CPU  Level 2  0.754609
# 14  mammals  HSNE CPU  Level 2  0.756074
# 15  mammals  HSNE CPU  Level 2  0.756086
# 16  mammals  HSNE CPU  Level 2  0.754548
# 17  mammals  HSNE CPU  Level 2  0.752919
# 18  mammals  HSNE CPU  Level 2  0.757841
# 19  mammals  HSNE CPU  Level 2  0.755883
# 20  mammals  HSNE CPU  Level 0  0.699939
# 21  mammals  HSNE CPU  Level 0  0.688520
# 22  mammals  HSNE CPU  Level 0  0.695372
# 23  mammals  HSNE CPU  Level 0  0.699499
# 24  mammals  HSNE CPU  Level 0  0.698528
# 25  mammals  HSNE CPU  Level 0  0.700925
# 26  mammals  HSNE CPU  Level 0  0.690744
# 27  mammals  HSNE CPU  Level 0  0.695786
# 28  mammals  HSNE CPU  Level 0  0.709079
# 29  mammals  HSNE CPU  Level 0  0.699291
# 30  mammals  HSNE CPU  Level 0  0.697660
# 31  mammals  HSNE CPU  Level 0  0.705123
# 32  mammals  HSNE CPU  Level 0  0.695189
# 33  mammals  HSNE CPU  Level 0  0.700294
# 34  mammals  HSNE CPU  Level 0  0.700221
# 35  mammals  HSNE CPU  Level 0  0.695319
# 36  mammals  HSNE CPU  Level 0  0.701535
# 37  mammals  HSNE CPU  Level 0  0.699541
# 38  mammals  HSNE CPU  Level 0  0.699057
# 39  mammals  HSNE CPU  Level 0  0.684241
