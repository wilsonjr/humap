# %%
import os
import scprep
import demap
import math
import random
import numpy as np
import pandas as pd
import hierarchical_umap as h_umap
import matplotlib.pyplot as plt

from tqdm import tqdm
from sklearn.neighbors import NearestNeighbors
from sklearn.utils import check_array
from sklearn.preprocessing import normalize, LabelEncoder
from sklearn.decomposition import PCA
from sklearn.metrics import euclidean_distances
from sklearn.neighbors import NearestNeighbors

from scipy.stats import pearsonr, spearmanr

# %%
def correlation(X, X_emb):
    
    dist_orig = np.square(euclidean_distances(X, X)).flatten()
    dist_emb = np.square(euclidean_distances(X_emb, X_emb)).flatten()
    
    
    coef, p = spearmanr(dist_orig, dist_emb)
    return coef

def stress(X, X_emb):
    
    DE = euclidean_distances(X_emb)
    DE = DE/np.max(DE)
    DH = euclidean_distances(X)
    DH = DH/np.max(DH)
    stress = 0.5 * np.sum((DE - DH)**2)
    
    return np.sqrt(stress/(0.5*np.sum(DH**2)))
    

def neighborhood_preservation(X, X_emb, Khigh=30):
    
    neigh_high = NearestNeighbors(n_neighbors=Khigh+1, n_jobs=-1)
    neigh_high.fit(X)
    high_dists, high_indices = neigh_high.kneighbors(X)


    neigh_emb = NearestNeighbors(n_neighbors=Khigh+1, n_jobs=-1)
    neigh_emb.fit(X_emb)
    emb_dists, emb_indices = neigh_emb.kneighbors(X_emb)

    npres = np.zeros(Khigh)
    
    for k in range(1, Khigh+1):
        for i in range(X.shape[0]):
            high_current = high_indices[i][1:k+1]
            emb_current = emb_indices[i][1:k+1]
            
            tp = len(np.intersect1d(high_current, emb_current))
            
            npres[k-1] += (tp/k)
        
        
    npres /= float(X.shape[0])
    
    return npres

# %%
def load_fmnist():
    fashionTrain = pd.read_csv('data/fashion-train.csv')

    fashionX = fashionTrain.values[:,2:]
    fashionY = fashionTrain.values[:, 1].astype(int)

    X = normalize(fashionX)
    y = fashionY

    X = check_array(X, dtype=np.float32, accept_sparse='csr', order='C')
    
    return X, y

def load_mnist():
    X = np.load('./data/MNIST_70000.npy')
    y = np.load('./data/MNIST_70000_label.npy').astype(int)
    X = normalize(X)
    X = check_array(X, dtype=np.float32, accept_sparse='csr', order='C')
    
    return X, y

def load_scRNAseq():
    download_path = os.path.expanduser("~/Documentos/HierarchicalUMAP/umap-cpp/umap/cpp/data")
    sparse=True
    T1 = scprep.io.load_10X(os.path.join(download_path, "scRNAseq", "T0_1A"), sparse=sparse, gene_labels='both')
    T2 = scprep.io.load_10X(os.path.join(download_path, "scRNAseq", "T2_3B"), sparse=sparse, gene_labels='both')
    T3 = scprep.io.load_10X(os.path.join(download_path, "scRNAseq", "T4_5C"), sparse=sparse, gene_labels='both')
    T4 = scprep.io.load_10X(os.path.join(download_path, "scRNAseq", "T6_7D"), sparse=sparse, gene_labels='both')
    T5 = scprep.io.load_10X(os.path.join(download_path, "scRNAseq", "T8_9E"), sparse=sparse, gene_labels='both')
    filtered_batches = []
    for batch in [T1, T2, T3, T4, T5]:
        batch = scprep.filter.filter_library_size(batch, percentile=20, keep_cells='above')
        batch = scprep.filter.filter_library_size(batch, percentile=75, keep_cells='below')
        filtered_batches.append(batch)
    del T1, T2, T3, T4, T5
    EBT_counts, sample_labels = scprep.utils.combine_batches(
        filtered_batches, 
        ["Day 00-03", "Day 06-09", "Day 12-15", "Day 18-21", "Day 24-27"],
        append_to_cell_names=True
    )
    del filtered_batches # removes objects from memory
    EBT_counts = scprep.filter.filter_rare_genes(EBT_counts, min_cells=10)
    EBT_counts = scprep.normalize.library_size_normalize(EBT_counts)
    mito_genes = scprep.select.get_gene_set(EBT_counts, starts_with="MT-") # Get all mitochondrial genes. There are 14, FYI.
    EBT_counts, sample_labels = scprep.filter.filter_gene_set_expression(
    EBT_counts, sample_labels, genes=mito_genes, 
    percentile=90, keep_cells='below')
    EBT_counts = scprep.transform.sqrt(EBT_counts)
    
    le = LabelEncoder()
    le.fit(sample_labels)
    labels = le.transform(sample_labels)
    X = PCA(n_components=50).fit_transform(EBT_counts.values)
    X = check_array(X, dtype=np.float32, accept_sparse='csr', order='C')
    return X, labels

def load_mammals():
    X = np.loadtxt("data/mammals-20000_features.txt")
    y = np.loadtxt("data/mammals-20000_classes.txt")
    X = normalize(X)
    
    return X, y

# %%
datasets = []
datasets.append({
    'load': load_mnist,
    'name': 'mnist-np'
})

# %%
def compute_metrics(datasets, techniques = ['hsne', 'humap0', 'humap30', 'humap50', 'humap70', 'humap100'], n_executions = 20):
    map_name = {}
    map_name['hsne'] = 'HSNE'
    map_name['humap0'] = 'HUMAP'
    map_name['humap30'] = 'HUMAP 30'
    map_name['humap50'] = 'HUMAP 50'
    map_name['humap70'] = 'HUMAP 70'
    map_name['humap100'] = 'HUMAP 100'
    
    
    
    corr_values = []
    corr_level = []
    corr_technique = []
    
    demap_values = []
    demap_level = []
    demap_technique = []
    
    neighborhood_values = []
    np_values = []
    np_level = []
    np_technique = []
    
    dataset_values_corr = []
    dataset_values_demap = []
    dataset_values_np = []
    
    size_before_corr = 0
    size_before_demap = 0
    size_before_np = 0
    
    for dataset in datasets:
        
        path = 'experiments/comparison/'+dataset['name']
        X, y = dataset['load']()
        
        print("DATASET: %s" % (dataset['name']))
        
                
        for technique in techniques:
            print("Technique: %s" % (technique))
                
            for i, level in enumerate(['_TOP.csv', '_level0.csv']):
                
                print("Level: %s" % (level))
                
                demap_list = []
                correlation_list = []
                np_list = []

                for execution in tqdm(range(n_executions)):
                    it = str(execution)
                    
                    df = pd.read_csv(path+'/'+technique+'_it'+it+level)
                    x = df['x'+it].values
                    y = df['y'+it].values
                    indices = df['inds'+it].values
                    
                    emb = np.stack((x, y), axis=-1)
                    sample = random.sample(range(0, len(x)), min(3000, len(x)))
                    
                    subset_emb = emb[sample]
                    subset_X = X[indices][sample]
                    
                    demap_value = demap.DEMaP(subset_X, subset_emb)
                    demap_list.append(demap_value)
                    
                    corr_value = correlation(subset_X, subset_emb)
                    correlation_list.append(corr_value)
                    
                    npres_values = neighborhood_preservation(subset_X, subset_emb)
                    np_list = np_list + npres_values.tolist()
                    
                    
                corr_values = corr_values + correlation_list
                corr_technique = corr_technique + [map_name[technique]]*len(correlation_list)
                level = 'Top'
                if i == 0:
                    level = 'Top'
                elif i == 1:
                    level = '0'
                corr_level = corr_level + ['Level '+str(level)]*len(correlation_list)
                
                demap_values = demap_values + demap_list
                demap_technique = demap_technique + [map_name[technique]]*len(demap_list)
                demap_level = demap_level + ['Level '+str(level)]*len(demap_list)
                
                np_values = np_values + np_list
                neighborhood_values = neighborhood_values + list(range(30))*n_executions
                np_technique = np_technique + [map_name[technique]]*len(np_list)
                np_level = np_level + ['Level '+str(level)]*len(np_list)
        
        
        dataset_values_corr = dataset_values_corr + [dataset['name']]*(len(corr_values) - size_before_corr)
        dataset_values_demap = dataset_values_demap + [dataset['name']]*(len(demap_values) - size_before_demap)
        dataset_values_np = dataset_values_np + [dataset['name']]*(len(np_values) - size_before_np)
        
        size_before_corr = len(corr_values)
        size_before_demap = len(demap_values)
        size_before_np = len(np_values)
        
        
        
    
    print(len(dataset_values_corr), len(corr_technique), len(corr_values))
    
    df_correlation = pd.DataFrame({
        'dataset': dataset_values_corr,
        'technique': corr_technique,
        'level': corr_level,
        'values': corr_values        
    })
    
    print(len(dataset_values_demap), len(demap_technique), len(demap_values))
    
    df_demap = pd.DataFrame({
        'dataset': dataset_values_demap,
        'technique': demap_technique,
        'level': demap_level,
        'values': demap_values
    })
    
    print(len(dataset_values_np), len(np_technique), len(neighborhood_values), len(np_values))
    
    
    df_np = pd.DataFrame({
        'dataset': dataset_values_np,
        'technique': np_technique,
        'level': np_level,
        'neighbors': neighborhood_values,
        'np': np_values
    })
        
    return df_correlation, df_demap, df_np

# %%
df_correlation, df_demap, df_np = compute_metrics(datasets, n_executions=20)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# DATASET: mnist-np
# Technique: hsne
# Level: _TOP.csv
# /home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2703, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#   5%|▌         | 1/20 [00:11<03:31, 11.16s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2717, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:22<03:21, 11.17s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2670, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:33<03:09, 11.12s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2707, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:44<02:57, 11.12s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2700, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [00:55<02:46, 11.10s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2701, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [01:06<02:35, 11.13s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2673, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [01:17<02:23, 11.07s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2725, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [01:29<02:14, 11.18s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2730, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [01:40<02:03, 11.27s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2651, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [01:51<01:50, 11.09s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2675, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [02:02<01:39, 11.07s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2667, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [02:13<01:28, 11.02s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2692, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [02:24<01:16, 10.99s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2683, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [02:34<01:05, 10.94s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2673, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [02:46<00:55, 11.00s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2721, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [02:57<00:44, 11.17s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2705, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [03:08<00:33, 11.18s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2683, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [03:20<00:22, 11.18s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2730, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [03:31<00:11, 11.29s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2732, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [03:42<00:00, 11.14s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# Level: _level0.csv
#   5%|▌         | 1/20 [00:15<04:49, 15.22s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:30<04:33, 15.17s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:44<04:14, 15.00s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:59<03:58, 14.88s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [01:13<03:40, 14.69s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [01:28<03:24, 14.64s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [01:42<03:09, 14.55s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [01:56<02:53, 14.45s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [02:11<02:38, 14.44s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [02:25<02:24, 14.47s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [02:40<02:09, 14.43s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [02:54<01:55, 14.39s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [03:08<01:40, 14.35s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [03:22<01:25, 14.32s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [03:37<01:11, 14.30s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [03:51<00:57, 14.25s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [04:05<00:42, 14.32s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [04:20<00:28, 14.31s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [04:34<00:14, 14.28s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [04:48<00:00, 14.43s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2703, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# Technique: humap0
# Level: _TOP.csv
#   5%|▌         | 1/20 [00:10<03:22, 10.64s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2717, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:21<03:11, 10.63s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2670, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:31<02:58, 10.51s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2707, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:41<02:48, 10.50s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2700, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [00:52<02:37, 10.47s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2701, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [01:02<02:26, 10.46s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2673, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [01:13<02:15, 10.39s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2725, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [01:23<02:05, 10.42s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2730, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [01:35<01:58, 10.74s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2651, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [01:46<01:49, 10.93s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2675, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [01:57<01:39, 11.06s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2667, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [02:08<01:28, 11.03s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2692, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [02:19<01:17, 11.03s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2683, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [02:30<01:06, 11.06s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2673, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [02:42<00:55, 11.10s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2721, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [02:53<00:44, 11.15s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2705, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [03:04<00:33, 11.21s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2683, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [03:15<00:22, 11.21s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2730, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [03:27<00:11, 11.28s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2732, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [03:38<00:00, 10.94s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# Level: _level0.csv
#   5%|▌         | 1/20 [00:13<04:20, 13.72s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:27<04:06, 13.71s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:41<03:52, 13.68s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:54<03:39, 13.69s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [01:08<03:24, 13.66s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [01:22<03:11, 13.68s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [01:35<02:57, 13.65s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [01:49<02:43, 13.63s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [02:03<02:30, 13.70s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [02:16<02:16, 13.67s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [02:30<02:03, 13.75s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [02:44<01:49, 13.69s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [02:57<01:35, 13.67s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [03:11<01:22, 13.69s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [03:25<01:08, 13.66s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [03:38<00:54, 13.70s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [03:52<00:41, 13.69s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [04:06<00:27, 13.71s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [04:20<00:13, 13.70s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [04:33<00:00, 13.68s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2703, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# Technique: humap30
# Level: _TOP.csv
#   5%|▌         | 1/20 [00:10<03:22, 10.64s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2717, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:21<03:11, 10.66s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2670, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:31<02:59, 10.53s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2707, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:42<02:48, 10.52s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2700, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [00:52<02:38, 10.54s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2701, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [01:03<02:27, 10.55s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2673, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [01:13<02:16, 10.50s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2725, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [01:24<02:06, 10.58s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2730, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [01:35<01:56, 10.59s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2651, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [01:45<01:44, 10.48s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2675, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [01:55<01:34, 10.50s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2667, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [02:06<01:23, 10.49s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2692, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [02:16<01:13, 10.48s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2683, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [02:27<01:02, 10.50s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2673, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [02:37<00:52, 10.46s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2721, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [02:48<00:42, 10.56s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2705, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [02:58<00:31, 10.57s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2683, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [03:09<00:21, 10.51s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2730, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [03:20<00:10, 10.59s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2732, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [03:31<00:00, 10.56s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# Level: _level0.csv
#   5%|▌         | 1/20 [00:13<04:19, 13.68s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:27<04:06, 13.70s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:41<03:52, 13.69s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:55<03:40, 13.80s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [01:09<03:30, 14.01s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [01:24<03:19, 14.23s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [01:38<03:05, 14.30s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [01:53<02:51, 14.32s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [02:07<02:37, 14.31s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [02:21<02:22, 14.29s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [02:36<02:08, 14.28s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [02:50<01:54, 14.34s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [03:04<01:40, 14.35s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [03:19<01:25, 14.32s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [03:33<01:11, 14.29s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [03:47<00:57, 14.27s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [04:01<00:42, 14.22s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [04:15<00:28, 14.23s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [04:30<00:14, 14.24s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [04:44<00:00, 14.21s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2703, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# Technique: humap50
# Level: _TOP.csv
#   5%|▌         | 1/20 [00:11<03:31, 11.12s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2717, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:22<03:20, 11.17s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2670, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:32<03:06, 10.97s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2707, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:43<02:55, 10.99s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2700, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [00:55<02:47, 11.18s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2701, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [01:06<02:36, 11.17s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2673, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [01:17<02:24, 11.10s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2725, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [01:29<02:14, 11.19s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2730, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [01:40<02:03, 11.22s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2651, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [01:51<01:50, 11.06s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2675, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [02:01<01:39, 11.00s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2667, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [02:12<01:27, 10.91s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2692, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [02:23<01:16, 10.93s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2683, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [02:34<01:05, 10.85s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2673, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [02:44<00:53, 10.77s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2721, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [02:55<00:43, 10.84s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2705, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [03:06<00:32, 10.85s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2683, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [03:17<00:21, 10.81s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2730, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [03:28<00:10, 10.97s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2732, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [03:39<00:00, 11.00s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# Level: _level0.csv
#   5%|▌         | 1/20 [00:14<04:38, 14.67s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:28<04:22, 14.57s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:43<04:05, 14.45s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:57<03:49, 14.37s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [01:11<03:34, 14.30s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [01:25<03:19, 14.24s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [01:39<03:05, 14.26s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [01:54<02:50, 14.25s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [02:09<02:39, 14.51s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [02:23<02:25, 14.59s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [02:38<02:12, 14.68s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [02:53<01:56, 14.58s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [03:07<01:41, 14.57s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [03:22<01:27, 14.62s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [03:37<01:13, 14.61s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [03:51<00:58, 14.66s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [04:06<00:43, 14.62s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [04:20<00:28, 14.47s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [04:34<00:14, 14.42s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [04:49<00:00, 14.46s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2703, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# Technique: humap70
# Level: _TOP.csv
#   5%|▌         | 1/20 [00:11<03:31, 11.13s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2717, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:22<03:20, 11.12s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2670, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:32<03:06, 10.97s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2707, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:43<02:55, 10.95s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2700, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [00:54<02:44, 10.95s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2701, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [01:05<02:33, 10.95s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2673, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [01:16<02:21, 10.87s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2725, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [01:27<02:11, 10.94s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2730, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [01:38<02:01, 11.03s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2651, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [01:49<01:49, 10.93s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2675, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [02:00<01:38, 10.93s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2667, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [02:10<01:26, 10.81s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2692, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [02:21<01:15, 10.82s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2683, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [02:32<01:04, 10.81s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2673, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [02:43<00:53, 10.79s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2721, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [02:54<00:43, 10.80s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2705, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [03:04<00:32, 10.81s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2683, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [03:15<00:21, 10.78s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2730, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [03:26<00:10, 10.91s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2732, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [03:37<00:00, 10.90s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# Level: _level0.csv
#   5%|▌         | 1/20 [00:14<04:29, 14.21s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:28<04:16, 14.23s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:42<04:01, 14.22s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:56<03:47, 14.23s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [01:11<03:34, 14.30s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [01:25<03:19, 14.22s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [01:39<03:04, 14.19s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [01:53<02:50, 14.21s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [02:07<02:35, 14.11s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [02:21<02:21, 14.10s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [02:35<02:06, 14.09s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [02:49<01:52, 14.06s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [03:03<01:38, 14.03s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [03:18<01:24, 14.11s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [03:32<01:11, 14.21s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [03:47<00:57, 14.29s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [04:01<00:42, 14.26s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [04:15<00:28, 14.31s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [04:30<00:14, 14.36s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [04:44<00:00, 14.23s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2703, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# Technique: humap100
# Level: _TOP.csv
#   5%|▌         | 1/20 [00:11<03:30, 11.08s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2717, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:22<03:19, 11.07s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2670, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:32<03:06, 10.95s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2707, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:43<02:54, 10.92s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2700, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [00:54<02:42, 10.84s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2701, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [01:05<02:31, 10.85s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2673, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [01:15<02:20, 10.78s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2725, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [01:26<02:09, 10.75s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2730, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [01:37<01:58, 10.79s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2651, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [01:47<01:46, 10.69s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2675, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [01:58<01:36, 10.72s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2667, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [02:09<01:25, 10.64s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2692, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [02:19<01:14, 10.71s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2683, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [02:30<01:04, 10.73s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2673, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [02:41<00:53, 10.73s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2721, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [02:52<00:43, 10.79s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2705, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [03:03<00:32, 10.82s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2683, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [03:14<00:21, 10.85s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2730, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [03:25<00:10, 10.95s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2732, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [03:36<00:00, 10.83s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# Level: _level0.csv
#   5%|▌         | 1/20 [00:14<04:37, 14.58s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:29<04:21, 14.55s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:43<04:07, 14.56s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:57<03:51, 14.48s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [01:11<03:35, 14.35s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [01:25<03:18, 14.20s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [01:40<03:04, 14.19s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [01:54<02:50, 14.21s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [02:08<02:37, 14.28s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [02:22<02:22, 14.26s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [02:36<02:07, 14.14s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [02:50<01:53, 14.14s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [03:05<01:39, 14.17s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [03:19<01:25, 14.25s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [03:33<01:10, 14.18s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [03:47<00:56, 14.10s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [04:01<00:42, 14.01s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [04:15<00:27, 13.96s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [04:29<00:13, 13.99s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [04:43<00:00, 14.17s/it]
# 240 240 240
# 240 240 240
# 7200 7200 7200 7200

# %%
df_correlation.to_csv('./correlation_values_np.csv', index=False)
df_demap.to_csv('./demap_values_np.csv', index=False)
df_np.to_csv('./np_values_np.csv', index=False)
