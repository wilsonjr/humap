# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = 'fmnist-drill'
technique = 'hsne'

# %%
data = pd.read_csv('comparison-drill/'+dataset+'/'+technique+'_it2_TOP.csv')
plt.scatter(data['x2'].values, data['y2'].values, c=data['label2'].values, alpha=0.8, cmap='Set1')

# %%
data = pd.read_csv('comparison-drill/'+dataset+'/'+technique+'_it2_level1.csv')
plt.scatter(data['x2'].values, data['y2'].values, c=data['label2'].values, alpha=0.8, cmap='Set1')

# %%
data = pd.read_csv('comparison-drill/'+dataset+'/'+technique+'_it2_level0.csv')
plt.scatter(data['x2'].values, data['y2'].values, c=data['label2'].values, alpha=0.8, cmap='Set1')
