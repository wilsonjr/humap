# %%
import os
import scprep
import demap
import math
import random
import numpy as np
import pandas as pd
import hierarchical_umap as h_umap
import matplotlib.pyplot as plt

from tqdm import tqdm
from sklearn.neighbors import NearestNeighbors
from sklearn.utils import check_array
from sklearn.preprocessing import normalize, LabelEncoder
from sklearn.decomposition import PCA
from sklearn.metrics import euclidean_distances
from sklearn.neighbors import NearestNeighbors

from scipy.stats import pearsonr, spearmanr

# %%
def correlation(X, X_emb):
    
    dist_orig = np.square(euclidean_distances(X, X)).flatten()
    dist_emb = np.square(euclidean_distances(X_emb, X_emb)).flatten()
    
    
    coef, p = spearmanr(dist_orig, dist_emb)
    return coef

def stress(X, X_emb):
    
    DE = euclidean_distances(X_emb)
    DE = DE/np.max(DE)
    DH = euclidean_distances(X)
    DH = DH/np.max(DH)
    stress = 0.5 * np.sum((DE - DH)**2)
    
    return np.sqrt(stress/(0.5*np.sum(DH**2)))
    

def neighborhood_preservation(X, X_emb, Khigh=30):
    
    neigh_high = NearestNeighbors(n_neighbors=Khigh+1, n_jobs=-1)
    neigh_high.fit(X)
    high_dists, high_indices = neigh_high.kneighbors(X)


    neigh_emb = NearestNeighbors(n_neighbors=Khigh+1, n_jobs=-1)
    neigh_emb.fit(X_emb)
    emb_dists, emb_indices = neigh_emb.kneighbors(X_emb)

    npres = np.zeros(Khigh)
    
    for k in range(1, Khigh+1):
        for i in range(X.shape[0]):
            high_current = high_indices[i][1:k+1]
            emb_current = emb_indices[i][1:k+1]
            
            tp = len(np.intersect1d(high_current, emb_current))
            
            npres[k-1] += (tp/k)
        
        
    npres /= float(X.shape[0])
    
    return npres

# %%
def load_fmnist():
    fashionTrain = pd.read_csv('data/fashion-train.csv')

    fashionX = fashionTrain.values[:,2:]
    fashionY = fashionTrain.values[:, 1].astype(int)

    X = normalize(fashionX)
    y = fashionY

    X = check_array(X, dtype=np.float32, accept_sparse='csr', order='C')
    
    return X, y

def load_mnist():
    X = np.load('./data/MNIST_70000.npy')
    y = np.load('./data/MNIST_70000_label.npy').astype(int)
    X = normalize(X)
    X = check_array(X, dtype=np.float32, accept_sparse='csr', order='C')
    
    return X, y

def load_scRNAseq():
    download_path = os.path.expanduser("~/Documentos/HierarchicalUMAP/umap-cpp/umap/cpp/data")
    sparse=True
    T1 = scprep.io.load_10X(os.path.join(download_path, "scRNAseq", "T0_1A"), sparse=sparse, gene_labels='both')
    T2 = scprep.io.load_10X(os.path.join(download_path, "scRNAseq", "T2_3B"), sparse=sparse, gene_labels='both')
    T3 = scprep.io.load_10X(os.path.join(download_path, "scRNAseq", "T4_5C"), sparse=sparse, gene_labels='both')
    T4 = scprep.io.load_10X(os.path.join(download_path, "scRNAseq", "T6_7D"), sparse=sparse, gene_labels='both')
    T5 = scprep.io.load_10X(os.path.join(download_path, "scRNAseq", "T8_9E"), sparse=sparse, gene_labels='both')
    filtered_batches = []
    for batch in [T1, T2, T3, T4, T5]:
        batch = scprep.filter.filter_library_size(batch, percentile=20, keep_cells='above')
        batch = scprep.filter.filter_library_size(batch, percentile=75, keep_cells='below')
        filtered_batches.append(batch)
    del T1, T2, T3, T4, T5
    EBT_counts, sample_labels = scprep.utils.combine_batches(
        filtered_batches, 
        ["Day 00-03", "Day 06-09", "Day 12-15", "Day 18-21", "Day 24-27"],
        append_to_cell_names=True
    )
    del filtered_batches # removes objects from memory
    EBT_counts = scprep.filter.filter_rare_genes(EBT_counts, min_cells=10)
    EBT_counts = scprep.normalize.library_size_normalize(EBT_counts)
    mito_genes = scprep.select.get_gene_set(EBT_counts, starts_with="MT-") # Get all mitochondrial genes. There are 14, FYI.
    EBT_counts, sample_labels = scprep.filter.filter_gene_set_expression(
    EBT_counts, sample_labels, genes=mito_genes, 
    percentile=90, keep_cells='below')
    EBT_counts = scprep.transform.sqrt(EBT_counts)
    
    le = LabelEncoder()
    le.fit(sample_labels)
    labels = le.transform(sample_labels)
    X = PCA(n_components=50).fit_transform(EBT_counts.values)
    X = check_array(X, dtype=np.float32, accept_sparse='csr', order='C')
    return X, labels

def load_mammals():
    X = np.loadtxt("data/mammals-20000_features.txt")
    y = np.loadtxt("data/mammals-20000_classes.txt")
    X = normalize(X)
    
    return X, y

# %%
datasets = []
datasets.append({
    'load': load_mnist,
    'name': 'mnist-np'
})

# %%
def compute_metrics(datasets, techniques = ['hsne', 'humap0', 'humap30', 'humap50', 'humap70', 'humap100'], n_executions = 20):
    map_name = {}
    map_name['hsne'] = 'HSNE'
    map_name['humap0'] = 'HUMAP'
    map_name['humap30'] = 'HUMAP 30'
    map_name['humap50'] = 'HUMAP 50'
    map_name['humap70'] = 'HUMAP 70'
    map_name['humap100'] = 'HUMAP 100'
    
    
    
    corr_values = []
    corr_level = []
    corr_technique = []
    
    demap_values = []
    demap_level = []
    demap_technique = []
    
    neighborhood_values = []
    np_values = []
    np_level = []
    np_technique = []
    
    dataset_values_corr = []
    dataset_values_demap = []
    dataset_values_np = []
    
    size_before_corr = 0
    size_before_demap = 0
    size_before_np = 0
    
    for dataset in datasets:
        
        path = 'experiments/comparison/'+dataset['name']
        X, y = dataset['load']()
        
        print("DATASET: %s" % (dataset['name']))
        
                
        for technique in techniques:
            print("Technique: %s" % (technique))
                
            for i, level in enumerate(['_TOP.csv', '_level0.csv']):
                
                print("Level: %s" % (level))
                
                demap_list = []
                correlation_list = []
                np_list = []

                for execution in tqdm(range(n_executions)):
                    it = str(execution)
                    
                    df = pd.read_csv(path+'/'+technique+'_it'+it+level)
                    x = df['x'+it].values
                    y = df['y'+it].values
                    indices = df['inds'+it].values
                    
                    emb = np.stack((x, y), axis=-1)
                    sample = random.sample(range(0, len(x)), min(3000, len(x)))
                    
                    subset_emb = emb[sample]
                    subset_X = X[indices][sample]
                    
                    demap_value = demap.DEMaP(subset_X, subset_emb)
                    demap_list.append(demap_value)
                    
                    corr_value = correlation(subset_X, subset_emb)
                    correlation_list.append(corr_value)
                    
                    npres_values = neighborhood_preservation(subset_X, subset_emb)
                    np_list = np_list + npres_values.tolist()
                    
                    
                corr_values = corr_values + correlation_list
                corr_technique = corr_technique + [map_name[technique]]*len(correlation_list)
                level = 'Top'
                if i == 0:
                    level = 'Top'
                elif i == 1:
                    level = '0'
                corr_level = corr_level + ['Level '+str(level)]*len(correlation_list)
                
                demap_values = demap_values + demap_list
                demap_technique = demap_technique + [map_name[technique]]*len(demap_list)
                demap_level = demap_level + ['Level '+str(level)]*len(demap_list)
                
                np_values = np_values + np_list
                neighborhood_values = neighborhood_values + list(range(30))*n_executions
                np_technique = np_technique + [map_name[technique]]*len(np_list)
                np_level = np_level + ['Level '+str(level)]*len(np_list)
        
        
        dataset_values_corr = dataset_values_corr + [dataset['name']]*(len(corr_values) - size_before_corr)
        dataset_values_demap = dataset_values_demap + [dataset['name']]*(len(demap_values) - size_before_demap)
        dataset_values_np = dataset_values_np + [dataset['name']]*(len(np_values) - size_before_np)
        
        size_before_corr = len(corr_values)
        size_before_demap = len(demap_values)
        size_before_np = len(np_values)
        
        
        
    
    print(len(dataset_values_corr), len(corr_technique), len(corr_values))
    
    df_correlation = pd.DataFrame({
        'dataset': dataset_values_corr,
        'technique': corr_technique,
        'level': corr_level,
        'values': corr_values        
    })
    
    print(len(dataset_values_demap), len(demap_technique), len(demap_values))
    
    df_demap = pd.DataFrame({
        'dataset': dataset_values_demap,
        'technique': demap_technique,
        'level': demap_level,
        'values': demap_values
    })
    
    print(len(dataset_values_np), len(np_technique), len(neighborhood_values), len(np_values))
    
    
    df_np = pd.DataFrame({
        'dataset': dataset_values_np,
        'technique': np_technique,
        'level': np_level,
        'neighbors': neighborhood_values,
        'np': np_values
    })
        
    return df_correlation, df_demap, df_np

# %%
df_correlation, df_demap, df_np = compute_metrics(datasets, n_executions=20)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# DATASET: mnist-np
# Technique: hsne
# Level: _TOP.csv
# /home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2687, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#   5%|▌         | 1/20 [00:11<03:30, 11.07s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2691, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:21<03:18, 11.01s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2677, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:32<03:06, 10.98s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2677, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:43<02:53, 10.87s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2702, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [00:54<02:42, 10.84s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2641, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [01:04<02:29, 10.69s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2722, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [01:16<02:23, 11.06s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2733, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [01:27<02:13, 11.12s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2761, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [01:39<02:03, 11.27s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2717, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [01:50<01:52, 11.27s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2735, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [02:01<01:41, 11.29s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2681, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [02:13<01:29, 11.24s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2733, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [02:24<01:18, 11.21s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2687, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [02:35<01:06, 11.13s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2700, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [02:46<00:55, 11.18s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2712, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [02:57<00:44, 11.15s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2667, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [03:08<00:32, 10.98s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2653, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [03:18<00:21, 10.81s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2690, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [03:29<00:10, 10.79s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2677, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [03:39<00:00, 11.00s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# Level: _level0.csv
#   5%|▌         | 1/20 [00:14<04:30, 14.25s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:28<04:15, 14.21s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:42<04:00, 14.14s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:56<03:46, 14.14s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [01:10<03:32, 14.18s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [01:24<03:18, 14.19s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [01:39<03:03, 14.15s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [01:53<02:49, 14.14s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [02:07<02:35, 14.18s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [02:21<02:22, 14.29s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [02:36<02:08, 14.30s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [02:50<01:53, 14.24s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [03:04<01:39, 14.18s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [03:18<01:24, 14.14s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [03:32<01:10, 14.10s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [03:46<00:56, 14.07s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [04:00<00:42, 14.15s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [04:15<00:28, 14.18s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [04:29<00:14, 14.14s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [04:43<00:00, 14.16s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2687, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# Technique: humap0
# Level: _TOP.csv
#   5%|▌         | 1/20 [00:10<03:28, 10.96s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2691, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:21<03:17, 10.96s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2677, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:32<03:03, 10.80s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2677, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:43<02:52, 10.77s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2702, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [00:53<02:41, 10.76s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2641, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [01:04<02:29, 10.67s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2722, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [01:15<02:20, 10.81s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2733, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [01:26<02:11, 10.93s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2761, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [01:38<02:01, 11.09s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2717, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [01:49<01:50, 11.08s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2735, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [02:00<01:40, 11.13s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2681, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [02:11<01:28, 11.04s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2733, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [02:22<01:17, 11.08s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2687, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [02:33<01:05, 10.99s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2699, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [02:43<00:54, 10.93s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2712, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [02:54<00:43, 10.92s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2667, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [03:05<00:32, 10.78s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2653, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [03:15<00:21, 10.71s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2690, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [03:26<00:10, 10.75s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2677, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [03:37<00:00, 10.86s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# Level: _level0.csv
#   5%|▌         | 1/20 [00:13<04:23, 13.86s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:27<04:10, 13.93s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:42<03:58, 14.01s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:56<03:44, 14.04s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [01:10<03:30, 14.05s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [01:24<03:16, 14.04s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [01:38<03:03, 14.14s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [01:52<02:49, 14.10s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [02:06<02:33, 13.98s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [02:19<02:18, 13.81s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [02:33<02:03, 13.68s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [02:46<01:48, 13.62s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [03:00<01:35, 13.58s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [03:13<01:21, 13.56s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [03:27<01:07, 13.56s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [03:40<00:54, 13.50s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [03:54<00:40, 13.50s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [04:07<00:26, 13.46s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [04:20<00:13, 13.46s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [04:34<00:00, 13.71s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2687, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# Technique: humap30
# Level: _TOP.csv
#   5%|▌         | 1/20 [00:10<03:16, 10.33s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2691, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:20<03:05, 10.33s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2677, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:30<02:55, 10.32s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2677, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:41<02:45, 10.32s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2702, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [00:51<02:35, 10.36s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2641, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [01:01<02:23, 10.22s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2722, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [01:12<02:13, 10.29s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2733, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [01:22<02:04, 10.41s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2761, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [01:33<01:55, 10.51s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2717, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [01:43<01:44, 10.49s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2735, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [01:54<01:34, 10.53s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2681, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [02:04<01:23, 10.44s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2733, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [02:15<01:13, 10.50s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2687, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [02:25<01:02, 10.44s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2699, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [02:36<00:52, 10.42s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2712, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [02:46<00:41, 10.42s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2667, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [02:56<00:31, 10.34s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2653, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [03:06<00:20, 10.30s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2690, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [03:17<00:10, 10.33s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2677, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [03:27<00:00, 10.38s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# Level: _level0.csv
#   5%|▌         | 1/20 [00:13<04:12, 13.31s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:26<03:59, 13.32s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:40<03:47, 13.36s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:53<03:34, 13.40s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [01:07<03:23, 13.59s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [01:21<03:11, 13.68s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [01:35<02:58, 13.76s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [01:49<02:45, 13.82s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [02:03<02:32, 13.90s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [02:17<02:19, 13.97s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [02:31<02:06, 14.03s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [02:45<01:52, 14.03s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [03:00<01:38, 14.06s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [03:14<01:24, 14.06s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [03:28<01:10, 14.07s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [03:42<00:56, 14.12s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [03:56<00:42, 14.10s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [04:10<00:28, 14.09s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [04:24<00:14, 14.11s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [04:38<00:00, 13.94s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2687, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# Technique: humap50
# Level: _TOP.csv
#   5%|▌         | 1/20 [00:10<03:24, 10.77s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2691, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:21<03:14, 10.81s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2677, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:32<03:02, 10.75s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2677, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:42<02:51, 10.69s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2702, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [00:53<02:40, 10.71s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2641, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [01:04<02:29, 10.67s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2722, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [01:15<02:20, 10.79s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2733, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [01:26<02:10, 10.84s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2761, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [01:37<02:01, 11.02s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2717, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [01:48<01:49, 10.97s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2735, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [01:59<01:38, 10.96s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2681, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [02:10<01:27, 10.89s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2733, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [02:21<01:17, 11.00s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2687, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [02:32<01:05, 10.90s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2699, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [02:42<00:54, 10.91s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2712, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [02:53<00:43, 10.93s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2667, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [03:04<00:32, 10.87s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2653, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [03:15<00:21, 10.74s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2690, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [03:25<00:10, 10.73s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2677, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [03:36<00:00, 10.82s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# Level: _level0.csv
#   5%|▌         | 1/20 [00:14<04:30, 14.22s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:28<04:15, 14.21s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:42<04:02, 14.28s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:57<03:48, 14.27s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [01:11<03:33, 14.24s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [01:25<03:19, 14.23s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [01:39<03:04, 14.19s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [01:53<02:50, 14.19s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [02:08<02:36, 14.21s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [02:22<02:21, 14.17s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [02:36<02:07, 14.20s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [02:50<01:53, 14.18s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [03:04<01:39, 14.20s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [03:19<01:25, 14.25s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [03:33<01:12, 14.43s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [03:48<00:57, 14.34s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [04:02<00:42, 14.32s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [04:16<00:28, 14.27s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [04:30<00:14, 14.23s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [04:44<00:00, 14.24s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2687, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# Technique: humap70
# Level: _TOP.csv
#   5%|▌         | 1/20 [00:10<03:17, 10.42s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2691, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:21<03:08, 10.48s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2677, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:31<02:57, 10.47s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2677, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:42<02:47, 10.49s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2702, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [00:52<02:38, 10.60s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2641, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [01:03<02:27, 10.51s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2722, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [01:13<02:17, 10.57s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2733, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [01:24<02:07, 10.67s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2761, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [01:36<01:59, 10.84s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2717, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [01:46<01:48, 10.85s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2735, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [01:57<01:37, 10.87s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2681, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [02:08<01:25, 10.74s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2733, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [02:19<01:15, 10.84s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2687, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [02:29<01:04, 10.77s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2699, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [02:40<00:54, 10.81s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2712, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [02:51<00:43, 10.90s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2667, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [03:02<00:32, 10.81s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2653, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [03:12<00:21, 10.68s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2690, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [03:23<00:10, 10.71s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2677, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [03:34<00:00, 10.71s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# Level: _level0.csv
#   5%|▌         | 1/20 [00:14<04:32, 14.33s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:28<04:16, 14.25s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:42<04:01, 14.21s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:56<03:45, 14.12s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [01:10<03:31, 14.13s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [01:24<03:18, 14.14s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [01:39<03:04, 14.18s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [01:53<02:49, 14.17s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [02:07<02:35, 14.18s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [02:21<02:21, 14.17s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [02:35<02:07, 14.19s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [02:49<01:53, 14.17s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [03:04<01:39, 14.20s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [03:18<01:24, 14.12s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [03:32<01:10, 14.16s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [03:46<00:56, 14.21s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [04:00<00:42, 14.20s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [04:14<00:28, 14.19s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [04:29<00:14, 14.24s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [04:43<00:00, 14.17s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2687, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# Technique: humap100
# Level: _TOP.csv
#   5%|▌         | 1/20 [00:10<03:22, 10.67s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2691, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:21<03:12, 10.67s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2677, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:31<02:59, 10.55s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2677, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:42<02:49, 10.62s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2702, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [00:52<02:38, 10.60s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2641, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [01:03<02:26, 10.45s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2722, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [01:14<02:18, 10.63s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2733, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [01:25<02:09, 10.76s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2761, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [01:36<02:00, 11.00s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2717, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [01:47<01:49, 10.99s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2735, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [01:59<01:40, 11.15s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2681, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [02:10<01:28, 11.08s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2733, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [02:21<01:17, 11.06s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2687, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [02:31<01:05, 10.93s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2699, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [02:42<00:54, 10.87s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2712, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [02:53<00:43, 10.79s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2667, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [03:03<00:32, 10.71s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2653, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [03:13<00:21, 10.57s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2690, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [03:24<00:10, 10.52s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2677, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [03:34<00:00, 10.74s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# Level: _level0.csv
#   5%|▌         | 1/20 [00:14<04:28, 14.14s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:28<04:14, 14.15s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:42<04:00, 14.15s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:56<03:46, 14.16s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [01:10<03:32, 14.17s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [01:25<03:18, 14.19s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [01:39<03:04, 14.16s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [01:53<02:51, 14.26s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [02:07<02:36, 14.26s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [02:22<02:22, 14.25s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [02:36<02:07, 14.20s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [02:50<01:53, 14.16s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [03:04<01:38, 14.14s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [03:18<01:24, 14.13s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [03:32<01:10, 14.15s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [03:46<00:56, 14.12s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [04:01<00:42, 14.18s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [04:15<00:28, 14.21s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [04:29<00:14, 14.25s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [04:43<00:00, 14.19s/it]
# 240 240 240
# 240 240 240
# 7200 7200 7200 7200

# %%
df_correlation.to_csv('./correlation_values_np.csv', index=False)
df_demap.to_csv('./demap_values_np.csv', index=False)
df_np.to_csv('./n0p_values_np.csv', index=False)

# %%
df_demap[df_demap['technique'] == 'HSNE CPU'][df_demap['dataset'] == 'mammals']
# Out:
# /home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#     dataset technique    level    values
# 0   mammals  HSNE CPU  Level 2  0.756441
# 1   mammals  HSNE CPU  Level 2  0.756594
# 2   mammals  HSNE CPU  Level 2  0.754914
# 3   mammals  HSNE CPU  Level 2  0.755382
# 4   mammals  HSNE CPU  Level 2  0.756958
# 5   mammals  HSNE CPU  Level 2  0.755487
# 6   mammals  HSNE CPU  Level 2  0.756064
# 7   mammals  HSNE CPU  Level 2  0.754787
# 8   mammals  HSNE CPU  Level 2  0.754383
# 9   mammals  HSNE CPU  Level 2  0.758107
# 10  mammals  HSNE CPU  Level 2  0.754942
# 11  mammals  HSNE CPU  Level 2  0.756204
# 12  mammals  HSNE CPU  Level 2  0.757184
# 13  mammals  HSNE CPU  Level 2  0.754609
# 14  mammals  HSNE CPU  Level 2  0.756074
# 15  mammals  HSNE CPU  Level 2  0.756086
# 16  mammals  HSNE CPU  Level 2  0.754548
# 17  mammals  HSNE CPU  Level 2  0.752919
# 18  mammals  HSNE CPU  Level 2  0.757841
# 19  mammals  HSNE CPU  Level 2  0.755883
# 20  mammals  HSNE CPU  Level 0  0.699939
# 21  mammals  HSNE CPU  Level 0  0.688520
# 22  mammals  HSNE CPU  Level 0  0.695372
# 23  mammals  HSNE CPU  Level 0  0.699499
# 24  mammals  HSNE CPU  Level 0  0.698528
# 25  mammals  HSNE CPU  Level 0  0.700925
# 26  mammals  HSNE CPU  Level 0  0.690744
# 27  mammals  HSNE CPU  Level 0  0.695786
# 28  mammals  HSNE CPU  Level 0  0.709079
# 29  mammals  HSNE CPU  Level 0  0.699291
# 30  mammals  HSNE CPU  Level 0  0.697660
# 31  mammals  HSNE CPU  Level 0  0.705123
# 32  mammals  HSNE CPU  Level 0  0.695189
# 33  mammals  HSNE CPU  Level 0  0.700294
# 34  mammals  HSNE CPU  Level 0  0.700221
# 35  mammals  HSNE CPU  Level 0  0.695319
# 36  mammals  HSNE CPU  Level 0  0.701535
# 37  mammals  HSNE CPU  Level 0  0.699541
# 38  mammals  HSNE CPU  Level 0  0.699057
# 39  mammals  HSNE CPU  Level 0  0.684241
