# %%
import os
import scprep
import demap
import math
import random
import numpy as np
import pandas as pd
import hierarchical_umap as h_umap
import matplotlib.pyplot as plt

from tqdm import tqdm
from sklearn.neighbors import NearestNeighbors
from sklearn.utils import check_array
from sklearn.preprocessing import normalize, LabelEncoder
from sklearn.decomposition import PCA
from sklearn.metrics import euclidean_distances
from sklearn.neighbors import NearestNeighbors

from scipy.stats import pearsonr, spearmanr

# %%
def correlation(X, X_emb):
    
    dist_orig = np.square(euclidean_distances(X, X)).flatten()
    dist_emb = np.square(euclidean_distances(X_emb, X_emb)).flatten()
    
    
    coef, p = spearmanr(dist_orig, dist_emb)
    return coef

def stress(X, X_emb):
    
    DE = euclidean_distances(X_emb)
    DE = DE/np.max(DE)
    DH = euclidean_distances(X)
    DH = DH/np.max(DH)
    stress = 0.5 * np.sum((DE - DH)**2)
    
    return np.sqrt(stress/(0.5*np.sum(DH**2)))
    

def neighborhood_preservation(X, X_emb, Khigh=30):
    
    neigh_high = NearestNeighbors(n_neighbors=Khigh+1, n_jobs=-1)
    neigh_high.fit(X)
    high_dists, high_indices = neigh_high.kneighbors(X)


    neigh_emb = NearestNeighbors(n_neighbors=Khigh+1, n_jobs=-1)
    neigh_emb.fit(X_emb)
    emb_dists, emb_indices = neigh_emb.kneighbors(X_emb)

    npres = np.zeros(Khigh)
    
    for k in range(1, Khigh+1):
        for i in range(X.shape[0]):
            high_current = high_indices[i][1:k+1]
            emb_current = emb_indices[i][1:k+1]
            
            tp = len(np.intersect1d(high_current, emb_current))
            
            npres[k-1] += (tp/k)
        
        
    npres /= float(X.shape[0])
    
    return npres

# %%
def load_fmnist():
    fashionTrain = pd.read_csv('data/fashion-train.csv')

    fashionX = fashionTrain.values[:,2:]
    fashionY = fashionTrain.values[:, 1].astype(int)

    X = normalize(fashionX)
    y = fashionY

    X = check_array(X, dtype=np.float32, accept_sparse='csr', order='C')
    
    return X, y

def load_mnist():
    X = np.load('./data/MNIST_70000.npy')
    y = np.load('./data/MNIST_70000_label.npy').astype(int)
    X = normalize(X)
    X = check_array(X, dtype=np.float32, accept_sparse='csr', order='C')
    
    return X, y

def load_scRNAseq():
    download_path = os.path.expanduser("~/Documentos/HierarchicalUMAP/umap-cpp/umap/cpp/data")
    sparse=True
    T1 = scprep.io.load_10X(os.path.join(download_path, "scRNAseq", "T0_1A"), sparse=sparse, gene_labels='both')
    T2 = scprep.io.load_10X(os.path.join(download_path, "scRNAseq", "T2_3B"), sparse=sparse, gene_labels='both')
    T3 = scprep.io.load_10X(os.path.join(download_path, "scRNAseq", "T4_5C"), sparse=sparse, gene_labels='both')
    T4 = scprep.io.load_10X(os.path.join(download_path, "scRNAseq", "T6_7D"), sparse=sparse, gene_labels='both')
    T5 = scprep.io.load_10X(os.path.join(download_path, "scRNAseq", "T8_9E"), sparse=sparse, gene_labels='both')
    filtered_batches = []
    for batch in [T1, T2, T3, T4, T5]:
        batch = scprep.filter.filter_library_size(batch, percentile=20, keep_cells='above')
        batch = scprep.filter.filter_library_size(batch, percentile=75, keep_cells='below')
        filtered_batches.append(batch)
    del T1, T2, T3, T4, T5
    EBT_counts, sample_labels = scprep.utils.combine_batches(
        filtered_batches, 
        ["Day 00-03", "Day 06-09", "Day 12-15", "Day 18-21", "Day 24-27"],
        append_to_cell_names=True
    )
    del filtered_batches # removes objects from memory
    EBT_counts = scprep.filter.filter_rare_genes(EBT_counts, min_cells=10)
    EBT_counts = scprep.normalize.library_size_normalize(EBT_counts)
    mito_genes = scprep.select.get_gene_set(EBT_counts, starts_with="MT-") # Get all mitochondrial genes. There are 14, FYI.
    EBT_counts, sample_labels = scprep.filter.filter_gene_set_expression(
    EBT_counts, sample_labels, genes=mito_genes, 
    percentile=90, keep_cells='below')
    EBT_counts = scprep.transform.sqrt(EBT_counts)
    
    le = LabelEncoder()
    le.fit(sample_labels)
    labels = le.transform(sample_labels)
    X = PCA(n_components=50).fit_transform(EBT_counts.values)
    X = check_array(X, dtype=np.float32, accept_sparse='csr', order='C')
    return X, labels

def load_mammals():
    X = np.loadtxt("data/mammals-20000_features.txt")
    y = np.loadtxt("data/mammals-20000_classes.txt")
    X = normalize(X)
    
    return X, y

# %%
datasets = []
datasets.append({
    'load': load_mammals,
    'name': 'mammals-drill'
})
# datasets.append({
#     'load': load_scRNAseq,
#     'name': 'scRNAseq'
# })
datasets.append({
    'load': load_fmnist,
    'name': 'fmnist-drill'
})
# datasets.append({
#     'load': load_mnist,
#     'name': 'mnist'
# })

# %%
def compute_metrics(datasets, techniques = ['hsne', 'humap'], n_executions = 20):
    map_name = {}
    map_name['hsne'] = 'HSNE'
    map_name['humap'] = 'HUMAP'
    
    
    corr_values = []
    corr_level = []
    corr_technique = []
    
    demap_values = []
    demap_level = []
    demap_technique = []
    
    neighborhood_values = []
    np_values = []
    np_level = []
    np_technique = []
    
    dataset_values_corr = []
    dataset_values_demap = []
    dataset_values_np = []
    
    size_before_corr = 0
    size_before_demap = 0
    size_before_np = 0
    
    for dataset in datasets:
        
        path = 'experiments/comparison/'+dataset['name']
        X, y = dataset['load']()
        
        print("DATASET: %s" % (dataset['name']))
        
                
        for technique in techniques:
            print("Technique: %s" % (technique))
                
            for i, level in enumerate(['_TOP.csv', '_level1.csv', '_level0.csv']):
                
                print("Level: %s" % (level))
                
                demap_list = []
                correlation_list = []
                np_list = []

                for execution in tqdm(range(n_executions)):
                    it = str(execution)
                    
                    df = pd.read_csv(path+'/'+technique+'_it'+it+level)
                    x = df['x'+it].values
                    y = df['y'+it].values
                    indices = df['inds'+it].values
                    
                    emb = np.stack((x, y), axis=-1)
                    sample = random.sample(range(0, len(x)), min(3000, len(x)))
                    
                    subset_emb = emb[sample]
                    subset_X = X[indices][sample]
                    
                    demap_value = demap.DEMaP(subset_X, subset_emb)
                    demap_list.append(demap_value)
                    
                    corr_value = correlation(subset_X, subset_emb)
                    correlation_list.append(corr_value)
                    
                    npres_values = neighborhood_preservation(subset_X, subset_emb)
                    np_list = np_list + npres_values.tolist()
                    
                    
                corr_values = corr_values + correlation_list
                corr_technique = corr_technique + [map_name[technique]]*len(correlation_list)
                level = 'Top'
                if i == 0:
                    level = 'Top'
                elif i == 1:
                    level = '1'
                elif i == 2:
                    level = '0'
                corr_level = corr_level + ['Level '+str(level)]*len(correlation_list)
                
                demap_values = demap_values + demap_list
                demap_technique = demap_technique + [map_name[technique]]*len(demap_list)
                demap_level = demap_level + ['Level '+str(level)]*len(demap_list)
                
                np_values = np_values + np_list
                neighborhood_values = neighborhood_values + list(range(30))*n_executions
                np_technique = np_technique + [map_name[technique]]*len(np_list)
                np_level = np_level + ['Level '+str(level)]*len(np_list)
        
        
        dataset_values_corr = dataset_values_corr + [dataset['name']]*(len(corr_values) - size_before_corr)
        dataset_values_demap = dataset_values_demap + [dataset['name']]*(len(demap_values) - size_before_demap)
        dataset_values_np = dataset_values_np + [dataset['name']]*(len(np_values) - size_before_np)
        
        size_before_corr = len(corr_values)
        size_before_demap = len(demap_values)
        size_before_np = len(np_values)
        
        
        
    
    print(len(dataset_values_corr), len(corr_technique), len(corr_values))
    
    df_correlation = pd.DataFrame({
        'dataset': dataset_values_corr,
        'technique': corr_technique,
        'level': corr_level,
        'values': corr_values        
    })
    
    print(len(dataset_values_demap), len(demap_technique), len(demap_values))
    
    df_demap = pd.DataFrame({
        'dataset': dataset_values_demap,
        'technique': demap_technique,
        'level': demap_level,
        'values': demap_values
    })
    
    print(len(dataset_values_np), len(np_technique), len(neighborhood_values), len(np_values))
    
    
    df_np = pd.DataFrame({
        'dataset': dataset_values_np,
        'technique': np_technique,
        'level': np_level,
        'neighbors': neighborhood_values,
        'np': np_values
    })
        
    return df_correlation, df_demap, df_np

# %%
df_correlation, df_demap, df_np = compute_metrics(datasets, n_executions=20)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# DATASET: mammals-drill
# Technique: hsne
# Level: _TOP.csv
# 100%|██████████| 20/20 [00:16<00:00,  1.20it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Level: _level1.csv
# 100%|██████████| 20/20 [02:24<00:00,  7.20s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Level: _level0.csv
# 100%|██████████| 20/20 [02:37<00:00,  7.86s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Technique: humap
# Level: _TOP.csv
# 100%|██████████| 20/20 [00:16<00:00,  1.23it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Level: _level1.csv
# 100%|██████████| 20/20 [02:24<00:00,  7.22s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Level: _level0.csv
# 100%|██████████| 20/20 [02:40<00:00,  8.01s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]
# DATASET: fmnist-drill
# Technique: hsne
# Level: _TOP.csv
# /home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (1969, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#   5%|▌         | 1/20 [00:05<01:47,  5.66s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (1973, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:11<01:40,  5.60s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2047, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:17<01:37,  5.71s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2038, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:22<01:32,  5.76s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2086, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [00:29<01:28,  5.89s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2005, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [00:34<01:21,  5.79s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2083, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [00:40<01:16,  5.86s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (1995, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [00:46<01:08,  5.74s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2064, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [00:52<01:03,  5.81s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2002, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [00:56<00:54,  5.48s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2026, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [01:02<00:49,  5.54s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2005, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [01:08<00:44,  5.53s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2033, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [01:13<00:38,  5.56s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2017, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [01:19<00:33,  5.57s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2081, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [01:25<00:28,  5.71s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (1989, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [01:30<00:22,  5.62s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (1986, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [01:35<00:16,  5.35s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (1999, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [01:41<00:10,  5.43s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (1988, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [01:46<00:05,  5.43s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2028, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [01:51<00:00,  5.58s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# Level: _level1.csv
#   5%|▌         | 1/20 [00:12<03:52, 12.23s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:24<03:41, 12.29s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:36<03:29, 12.30s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:49<03:17, 12.33s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [01:01<03:04, 12.32s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [01:14<02:52, 12.34s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [01:26<02:40, 12.36s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [01:38<02:28, 12.35s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [01:51<02:16, 12.38s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [02:03<02:03, 12.38s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [02:15<01:51, 12.37s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [02:28<01:38, 12.33s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [02:40<01:26, 12.34s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [02:52<01:14, 12.34s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [03:05<01:01, 12.38s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [03:17<00:49, 12.39s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [03:30<00:37, 12.37s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [03:42<00:24, 12.30s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [03:54<00:12, 12.29s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [04:06<00:00, 12.34s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# Level: _level0.csv
#   5%|▌         | 1/20 [00:13<04:15, 13.46s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:26<04:01, 13.42s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:40<03:47, 13.41s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:53<03:34, 13.39s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [01:06<03:20, 13.39s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [01:20<03:07, 13.38s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [01:33<02:53, 13.37s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [01:46<02:40, 13.36s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [02:00<02:27, 13.38s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [02:13<02:14, 13.43s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [02:27<02:00, 13.41s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [02:40<01:47, 13.40s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [02:54<01:33, 13.40s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [03:08<01:21, 13.62s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [03:21<01:07, 13.59s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [03:35<00:54, 13.55s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [03:48<00:40, 13.48s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [04:01<00:26, 13.45s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [04:15<00:13, 13.44s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [04:28<00:00, 13.44s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (1968, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# Technique: humap
# Level: _TOP.csv
#   5%|▌         | 1/20 [00:05<01:41,  5.35s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (1973, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:10<01:36,  5.36s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2047, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:16<01:33,  5.50s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2038, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:22<01:29,  5.57s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2086, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [00:28<01:26,  5.77s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2005, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [00:34<01:20,  5.73s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2083, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [00:40<01:16,  5.91s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (1995, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [00:46<01:11,  5.97s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2064, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [00:52<01:06,  6.02s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2002, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [00:58<00:59,  5.91s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2026, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [01:04<00:54,  6.07s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2005, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [01:10<00:47,  5.97s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2033, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [01:16<00:42,  6.02s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2017, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [01:22<00:36,  6.06s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2081, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [01:29<00:30,  6.18s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (1989, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [01:35<00:24,  6.06s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (1986, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [01:40<00:17,  5.94s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (1999, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [01:46<00:11,  5.87s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (1988, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [01:52<00:05,  5.81s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (2028, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [01:58<00:00,  5.90s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# Level: _level1.csv
#   5%|▌         | 1/20 [00:12<03:57, 12.52s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:25<03:48, 12.68s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:38<03:38, 12.84s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:51<03:24, 12.79s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [01:04<03:10, 12.72s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [01:17<03:01, 12.94s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [01:30<02:49, 13.03s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [01:43<02:37, 13.10s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [01:56<02:23, 13.02s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [02:09<02:10, 13.07s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [02:23<01:58, 13.13s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [02:35<01:43, 12.99s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [02:48<01:29, 12.74s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [03:00<01:15, 12.61s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [03:12<01:02, 12.52s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [03:25<00:49, 12.46s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [03:37<00:37, 12.41s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [03:49<00:24, 12.49s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [04:03<00:12, 12.69s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [04:16<00:00, 12.81s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# Level: _level0.csv
#   5%|▌         | 1/20 [00:14<04:32, 14.36s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  10%|█         | 2/20 [00:28<04:19, 14.41s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  15%|█▌        | 3/20 [00:43<04:05, 14.43s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  20%|██        | 4/20 [00:57<03:50, 14.38s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  25%|██▌       | 5/20 [01:12<03:37, 14.49s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  30%|███       | 6/20 [01:26<03:21, 14.43s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  35%|███▌      | 7/20 [01:40<03:06, 14.32s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  40%|████      | 8/20 [01:54<02:49, 14.15s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  45%|████▌     | 9/20 [02:07<02:32, 13.89s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  50%|█████     | 10/20 [02:21<02:17, 13.75s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  55%|█████▌    | 11/20 [02:34<02:02, 13.65s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  60%|██████    | 12/20 [02:48<01:48, 13.61s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  65%|██████▌   | 13/20 [03:01<01:34, 13.53s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  70%|███████   | 14/20 [03:14<01:20, 13.47s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  75%|███████▌  | 15/20 [03:28<01:07, 13.44s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  80%|████████  | 16/20 [03:41<00:53, 13.44s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  85%|████████▌ | 17/20 [03:55<00:40, 13.44s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  90%|█████████ | 18/20 [04:08<00:26, 13.45s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
#  95%|█████████▌| 19/20 [04:21<00:13, 13.42s/it]/home/wilson/anaconda3/envs/py37/lib/python3.7/site-packages/graphtools/graphs.py:121: UserWarning: Building a kNNGraph on data of shape (3000, 784) is expensive. Consider setting n_pca.
#   UserWarning,
# 100%|██████████| 20/20 [04:35<00:00, 13.76s/it]
# 240 240 240
# 240 240 240
# 7200 7200 7200 7200

# %%
df_correlation.to_csv('./correlation_values_drill.csv', index=False)
df_demap.to_csv('./demap_values_drill.csv', index=False)
df_np.to_csv('./np_values_drill.csv', index=False)
