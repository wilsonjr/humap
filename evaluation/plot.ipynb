# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = 'fmnist'
technique = 'humap'

# %%
data = pd.read_csv('comparison-techniques/'+dataset+'/'+technique+'_it0_level2.csv')
plt.scatter(data['x0'].values, data['y0'].values, c=data['label0'].values, alpha=0.8, cmap='tab10')

# %%
data = pd.read_csv('comparison-techniques/'+dataset+'/'+technique+'_it0_level1.csv')
plt.scatter(data['x0'].values, data['y0'].values, c=data['label0'].values, alpha=0.8, cmap='tab10')

# %%
data = pd.read_csv('comparison-techniques/'+dataset+'/'+technique+'_it0_level0.csv')
plt.scatter(data['x0'].values, data['y0'].values, c=data['label0'].values, alpha=0.8, cmap='tab10')
